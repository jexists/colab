# %%
import pandas as pd

# %% [markdown]
# Dict 사용 데이터 프레임 생성

# %%
df = pd.DataFrame({'a':[1,2,3],'b':[4,5,6],'c':[7,8,9]})

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
use_dict = {'a':[1,2,3],'b':[4,5,6],'c':[7,8,9]}

# %%
df2 = pd.DataFrame(use_dict)

# %%
df2
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %% [markdown]
# List 사용 데이터 프레임 생성

# %%
use_list = [[1,4,7],[2,5,8],[3,6,9]]

# %%
df3 = pd.DataFrame(use_list)

# %%
df3
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df3.columns=['a','b','c']

# %%
df3
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %% [markdown]
# 빈값

# %%
import numpy as np

# %%
use_list_null = {'type': ['string','한국어',123], 'number':[700,10,5], 'test': ['hello',, 'world']}
# Out:
#   File "<ipython-input-5-4ec683c853f1>", line 1
#     use_list_null = {'type': ['string','한국어',123], 'number':[700,10,5], 'test': ['hello',, 'world']}
#                                                                                          ^
# SyntaxError: invalid syntax

# %%
use_list_null = {'type': ['string','한국어',123], 'number':[700,10,5], 'test': ['hello',NaN, 'world']}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-aa2fdd485401> in <module>()
# ----> 1 use_list_null = {'type': ['string','한국어',123], 'number':[700,10,5], 'test': ['hello',NaN, 'world']}
#
# NameError: name 'NaN' is not defined

# %%
use_any_type = {'type': ['string','한국어',123], 'number':[700,10,5], 'test': ['hello',np.NaN, 'world']}

# %%
df5 = pd.DataFrame(use_any_type)

# %%
df5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6986fd1f5b9d> in <module>()
# ----> 1 df5
#
# NameError: name 'df5' is not defined

# %% [markdown]
# 런타입 -> 런타입 유형 변경 -> GPU
#
# GPU 기능 확인

# %%
# !nvidia-smi
# Out:
# Fri Jun  3 13:32:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
